# %%
import pandas as pd
import glob

train_path = "dataset/train/training-data.csv"
test_path = "dataset/test"
validate_path = "dataset/valid"

train_filenames = glob.glob(train_path + "\*.csv")
validate_filenames = glob.glob(validate_path + "\*.csv")

train_df = pd.read_csv(train_path)
train_df.head()
# Out:
#      time  f1_c  f1_a  f1_s  f1_d  f2_c  f2_a  f2_s  f2_d  prg_c  ...   pr_s  \
# 0  0.0000     0     0     0     0  1851  1831   155     0      0  ...  53281
# 1  0.1083     0     0     0     0  1851  1831   155     0      0  ...  53281
# 2  0.2103     0     0     0     0  1851  1831   155     0      0  ...  53281
# 3  0.3121     0     0     0     0  1851  1831   155     0      0  ...  53281
# 4  0.4141     0     0     0     0  1851  1831   155     0      0  ...  53281
#
#    pr_d   lq_s  lq_d  cmp_a_s  cmp_a_d  cmp_b_s  cmp_b_d  cmp_c_s  cmp_c_d
# 0     0  28700     0    30781        0     1186        0    33567        0
# 1     0  28700     0    30781        0     1186        0    33567        0
# 2     0  28700     0    30781        0     1186        0    33567        0
# 3     0  28700     0    30781        0     1186        0    33567        0
# 4     0  28700     0    30781        0     1186        0    33567        0
#
# [5 rows x 27 columns]

# %%
# importing packages
import pandas as pd
import glob
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

train_path = r"dataset\dataset\train"
train_list = glob.glob(train_path + "/*.csv")
df = pd.DataFrame(pd.read_csv(train_list[0]))
for i in range(1,len(train_list)):
    data = pd.read_csv(train_list[i])
    df = pd.DataFrame(data)
    train_df = pd.concat([train_df,df],axis=1)

#Statistical Analysis of all the features/dataset (remove comments if you need to run!!!)

#df.describe()
#df.hist(figsize = (15,15))
#df[['f1_d', 'f2_d', 'prg_d', 'prd_d', 'pr_d', 'lq_d', 'cmp_a_d', 'cmp_b_d', 'cmp_c_d']].boxplot(figsize = (15,15))
#df['f1_c'].plot.kde(figsize = (15,15))
#df['f2_a'].plot.kde(figsize = (15,15))
#df['prg_s'].plot.kde(figsize = (15,15))
#df['prd_c'].plot.box(figsize = (15,15))
#df['pr_s'].plot.box(figsize = (15,15))
#df['lq_s'].plot.box(figsize = (15,15))
#df['cmp_a_s'].plot.box(figsize = (15,15))
#df['cmp_b_s'].plot.box(figsize = (15,15))
#df['cmp_c_s'].plot.box(figsize = (15,15))
# Out:
# <AxesSubplot:>
