# %%
import pandas as pd
import glob

train_path = "dataset/train/training-data.csv"
test_path = "dataset/test"
validate_path = "dataset/valid"

train_filenames = glob.glob(train_path + "\*.csv")
validate_filenames = glob.glob(validate_path + "\*.csv")

train_df = pd.read_csv(train_path)
train_df.head()
# Out:
#      time  f1_c  f1_a  f1_s  f1_d  f2_c  f2_a  f2_s  f2_d  prg_c  ...   pr_s  \
# 0  0.0000     0     0     0     0  1851  1831   155     0      0  ...  53281
# 1  0.1083     0     0     0     0  1851  1831   155     0      0  ...  53281
# 2  0.2103     0     0     0     0  1851  1831   155     0      0  ...  53281
# 3  0.3121     0     0     0     0  1851  1831   155     0      0  ...  53281
# 4  0.4141     0     0     0     0  1851  1831   155     0      0  ...  53281
#
#    pr_d   lq_s  lq_d  cmp_a_s  cmp_a_d  cmp_b_s  cmp_b_d  cmp_c_s  cmp_c_d
# 0     0  28700     0    30781        0     1186        0    33567        0
# 1     0  28700     0    30781        0     1186        0    33567        0
# 2     0  28700     0    30781        0     1186        0    33567        0
# 3     0  28700     0    30781        0     1186        0    33567        0
# 4     0  28700     0    30781        0     1186        0    33567        0
#
# [5 rows x 27 columns]

# %%
# importing packages
import pandas as pd
import glob
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

train_path = r"dataset\train"
train_list = glob.glob(train_path + "/*.csv")
df = pd.DataFrame(pd.read_csv(train_list[0]))
for i in range(1,len(train_list)):
    data = pd.read_csv(train_list[i])
    df = pd.DataFrame(data)

#Statistical Analysis of all the features/dataset (remove comments if you need to run!!!)

df.describe()
#df.hist(figsize = (15,15))
#df[['f1_d', 'f2_d', 'prg_d', 'prd_d', 'pr_d', 'lq_d', 'cmp_a_d', 'cmp_b_d', 'cmp_c_d']].boxplot(figsize = (15,15))
#df['f1_c'].plot.kde(figsize = (15,15))
#df['f2_a'].plot.kde(figsize = (15,15))
#df['prg_s'].plot.kde(figsize = (15,15))
#df['prd_c'].plot.box(figsize = (15,15))
#df['pr_s'].plot.box(figsize = (15,15))
#df['lq_s'].plot.box(figsize = (15,15))
#df['cmp_a_s'].plot.box(figsize = (15,15))
#df['cmp_b_s'].plot.box(figsize = (15,15))
#df['cmp_c_s'].plot.box(figsize = (15,15))
# Out:
#               time          f1_c          f1_a          f1_s          f1_d  \
# count  9785.000000   9785.000000   9785.000000   9785.000000   9785.000000
# mean    499.793760  41803.568114  41753.387328  42298.660092      6.697496
# std     288.654711  30608.408812  30637.885196  30671.910502   1268.971853
# min       0.000000      0.000000      0.000000      0.000000 -23959.000000
# 25%     249.826600      0.000000      0.000000      0.000000      0.000000
# 50%     499.684900  65535.000000  65535.000000  65535.000000      0.000000
# 75%     749.803300  65535.000000  65535.000000  65535.000000      0.000000
# max     999.583900  65535.000000  65535.000000  65535.000000  21110.000000
#
#               f2_c         f2_a         f2_s         f2_d         prg_c  ...  \
# count  9785.000000  9785.000000  9785.000000  9785.000000   9785.000000  ...
# mean   2145.057741  2144.910169   181.651916     0.000613   6527.641799  ...
# std     350.530231   350.501435    29.766917     0.476984  18408.604770  ...
# min    1509.000000  1509.000000   128.000000    -3.000000      0.000000  ...
# 25%    1819.000000  1819.000000   154.000000     0.000000      0.000000  ...
# 50%    2204.000000  2204.000000   187.000000     0.000000      0.000000  ...
# 75%    2449.000000  2449.000000   207.000000     0.000000      0.000000  ...
# max    2726.000000  2725.000000   231.000000     3.000000  65535.000000  ...
#
#                pr_s         pr_d          lq_s         lq_d       cmp_a_s  \
# count   9785.000000  9785.000000   9785.000000  9785.000000   9785.000000
# mean   54576.384159     0.192335  28838.920286     0.029739  30800.854165
# std      673.933161    26.702247    119.493884     1.817016     16.936099
# min    53044.000000  -284.000000  28670.000000   -15.000000  30771.000000
# 25%    54008.000000     0.000000  28720.000000     0.000000  30786.000000
# 50%    54831.000000     0.000000  28837.000000     0.000000  30801.000000
# 75%    55140.000000     0.000000  28959.000000     0.000000  30816.000000
# max    55432.000000    71.000000  29009.000000     9.000000  30830.000000
#
#            cmp_a_d      cmp_b_s      cmp_b_d       cmp_c_s      cmp_c_d
# count  9785.000000  9785.000000  9785.000000   9785.000000  9785.000000
# mean      0.004803  1076.349004    -0.021053  33656.280634     0.016147
# std       0.312059    51.351767     0.263566     49.030913     0.143491
# min      -2.000000   980.000000    -1.000000  33567.000000    -1.000000
# 25%       0.000000  1034.000000     0.000000  33617.000000     0.000000
# 50%       0.000000  1073.000000     0.000000  33660.000000     0.000000
# 75%       0.000000  1117.000000     0.000000  33694.000000     0.000000
# max       1.000000  1191.000000     1.000000  33733.000000     1.000000
#
# [8 rows x 27 columns]

# %%
#Plot histograms for all features for analysis

import pandas as pd
import glob
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import gridspec

train_path = r"dataset\train"
train_list = glob.glob(train_path + "/*.csv")
df = pd.DataFrame(pd.read_csv(train_list[0]))
for i in range(1,len(train_list)):
    data = pd.read_csv(train_list[i])
    df = pd.DataFrame(data)

v_features = df.iloc[:,1:29].columns

plt.figure(figsize=(25, 8 * 4))
gs = gridspec.GridSpec(7, 4)
for i, cn in enumerate(df[v_features]):
    ax = plt.subplot(gs[i])
    sns.histplot(df[cn][df['f1_d'] == 1], bins = 50)
    sns.histplot(df[cn][df['f1_a'] == 0], bins = 50)
    ax.set_xlabel('')
    ax.set_title('Feature: ' + str(cn))
plt.show()

# %%
#Plot abnormal dataset for analysis

df = pd.DataFrame(pd.read_csv('dataset/test/2.csv'))
v_features = df.iloc[:,1:29].columns
plt.figure(figsize=(25, 8 * 4))
gs = gridspec.GridSpec(7, 4)
for i, cn in enumerate(df[v_features]):
    ax = plt.subplot(gs[i])
    sns.histplot(df[cn][df['f1_d'] == 1], bins = 50)
    sns.histplot(df[cn][df['f1_a'] == 0], bins = 50)
    ax.set_xlabel('')
    ax.set_title('Feature: ' + str(cn))
plt.show()

# %%
#Plot normal dataset for analysis

df = pd.DataFrame(pd.read_csv('dataset/test/3.csv'))
v_features = df.iloc[:,1:29].columns
plt.figure(figsize=(25, 8 * 4))
gs = gridspec.GridSpec(7, 4)
for i, cn in enumerate(df[v_features]):
    ax = plt.subplot(gs[i])
    sns.histplot(df[cn][df['f1_d'] == 1], bins = 50)
    sns.histplot(df[cn][df['f1_a'] == 0], bins = 50)
    ax.set_xlabel('')
    ax.set_title('Feature: ' + str(cn))
plt.show()
